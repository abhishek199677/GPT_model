# %%
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np
import os
import pickle

# %%
with open("data.txt",'r',encoding='utf-8') as f :
    text_data  = f.read()

# %%
text_data
# Out:
# '"The old, creaky door swung open, revealing a narrow stairway that descended deep into the darkness. The air that wafted up was musty and damp, filled with the scent of decay and rot. I hesitated for a moment, my heart pounding in my chest, as I wondered what secrets lay hidden beneath the earth. The stairs seemed to stretch on forever, disappearing into the shadows like a ghostly finger, beckoning me to follow. I took a deep breath, steeling myself for what lay ahead, and began my descent into the unknown. The stairs creaked and groaned beneath my feet, as if protesting my presence, and I had to feel my way down, my hands outstretched in front of me like a blind person. The darkness was absolute, a palpable thing that wrapped itself around me like a shroud. I stumbled, my foot catching on a loose step, and almost fell, but managed to catch myself just in time. As I continued down, the air grew colder, the silence more oppressive, and I began to feel like I was being watched. I spun around, but there was nothing to see, just the faint glow of a distant light, a light that seemed to be calling to me. I followed it, my heart pounding in my chest, until I reached a small, damp chamber deep beneath the earth. The room was filled with old, dusty artifacts, relics of a long-forgotten civilization, and in the center of the room, a large, stone sarcophagus sat atop a pedestal, adorned with strange symbols and markings. I approached it cautiously, feeling a sense of reverence wash over me, as if I was in the presence of something sacred. And then, I saw it, a small, leather-bound book, lying open on top of the sarcophagus, its pages filled with a language I couldn\'t understand. I reached out a trembling hand, and as I touched the book, the symbols on the pages began to glow, illuminating the dark chamber with a soft, ethereal light. I felt a surge of energy run through me, as if the book was imparting its secrets to me, and I knew that I had stumbled upon something incredible, something that could change my life forever."'

# %%
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=5000,oov_token='<OOV>')
tokenizer.fit_on_texts([text_data])

# %%
tokenizer

# %%
sequence = tokenizer.texts_to_sequences([text_data])[0]

# %%
sequence
# Out:
# [2,
#  27,
#  61,
#  62,
#  63,
#  28,
#  64,
#  3,
#  65,
#  66,
#  11,
#  67,
#  17,
#  18,
#  2,
#  29,
#  2,
#  30,
#  11,
#  68,
#  69,
#  9,
#  70,
#  5,
#  31,
#  19,
#  14,
#  2,
#  71,
#  8,
#  72,
#  5,
#  73,
#  4,
#  74,
#  32,
#  3,
#  75,
#  6,
#  33,
#  34,
#  12,
#  6,
#  35,
#  13,
#  4,
#  76,
#  36,
#  37,
#  38,
#  77,
#  20,
#  2,
#  39,
#  2,
#  40,
#  41,
#  7,
#  78,
#  15,
#  42,
#  79,
#  18,
#  2,
#  80,
#  16,
#  3,
#  81,
#  82,
#  83,
#  10,
#  7,
#  84,
#  4,
#  85,
#  3,
#  17,
#  86,
#  87,
#  43,
#  32,
#  36,
#  38,
#  88,
#  5,
#  21,
#  6,
#  89,
#  18,
#  2,
#  90,
#  2,
#  40,
#  91,
#  5,
#  92,
#  20,
#  6,
#  93,
#  13,
#  22,
#  94,
#  6,
#  44,
#  5,
#  4,
#  45,
#  7,
#  46,
#  6,
#  95,
#  47,
#  6,
#  96,
#  97,
#  12,
#  98,
#  8,
#  10,
#  16,
#  3,
#  99,
#  100,
#  2,
#  29,
#  9,
#  101,
#  3,
#  102,
#  103,
#  11,
#  104,
#  105,
#  48,
#  10,
#  16,
#  3,
#  106,
#  4,
#  49,
#  6,
#  107,
#  108,
#  15,
#  3,
#  109,
#  110,
#  5,
#  111,
#  112,
#  50,
#  113,
#  7,
#  114,
#  43,
#  51,
#  12,
#  115,
#  13,
#  4,
#  116,
#  47,
#  2,
#  30,
#  117,
#  118,
#  2,
#  119,
#  120,
#  121,
#  5,
#  4,
#  21,
#  7,
#  46,
#  16,
#  4,
#  9,
#  122,
#  123,
#  4,
#  124,
#  48,
#  50,
#  125,
#  9,
#  126,
#  7,
#  127,
#  51,
#  2,
#  128,
#  52,
#  8,
#  3,
#  129,
#  23,
#  3,
#  23,
#  11,
#  41,
#  7,
#  130,
#  131,
#  7,
#  10,
#  4,
#  132,
#  24,
#  6,
#  33,
#  34,
#  12,
#  6,
#  35,
#  133,
#  4,
#  53,
#  3,
#  54,
#  31,
#  55,
#  17,
#  20,
#  2,
#  39,
#  2,
#  56,
#  9,
#  19,
#  14,
#  27,
#  134,
#  135,
#  136,
#  8,
#  3,
#  137,
#  138,
#  139,
#  5,
#  12,
#  2,
#  140,
#  8,
#  2,
#  56,
#  3,
#  141,
#  142,
#  57,
#  143,
#  144,
#  3,
#  145,
#  146,
#  14,
#  147,
#  58,
#  5,
#  148,
#  4,
#  149,
#  24,
#  150,
#  151,
#  3,
#  152,
#  8,
#  153,
#  154,
#  155,
#  10,
#  13,
#  22,
#  4,
#  9,
#  12,
#  2,
#  44,
#  8,
#  25,
#  156,
#  5,
#  157,
#  4,
#  158,
#  24,
#  3,
#  54,
#  159,
#  160,
#  26,
#  161,
#  28,
#  15,
#  162,
#  8,
#  2,
#  57,
#  59,
#  60,
#  19,
#  14,
#  3,
#  163,
#  4,
#  164,
#  165,
#  4,
#  53,
#  166,
#  3,
#  167,
#  168,
#  5,
#  13,
#  4,
#  169,
#  2,
#  26,
#  2,
#  58,
#  15,
#  2,
#  60,
#  21,
#  7,
#  52,
#  170,
#  2,
#  171,
#  55,
#  14,
#  3,
#  172,
#  173,
#  23,
#  4,
#  174,
#  3,
#  175,
#  8,
#  176,
#  177,
#  178,
#  10,
#  13,
#  22,
#  2,
#  26,
#  9,
#  179,
#  59,
#  37,
#  7,
#  10,
#  5,
#  4,
#  180,
#  11,
#  4,
#  45,
#  49,
#  181,
#  25,
#  182,
#  25,
#  11,
#  183,
#  184,
#  6,
#  185,
#  42]

# %%
len(sequence)
# Out:
# 374

# %%
with open("tokenizer.pkl",'wb')  as f :
    pickle.dump(tokenizer,f)

# %%
max_seq_length = 100
def create_dataset(seq,window_size = max_seq_length):
    input ,labels = [],[]
    for i in range(len(seq) -window_size):
        input.append(seq[i:i+window_size])
        labels.append(seq[i+1:i+window_size+1])
    return np.array(input) , np.array(labels)

# %%
x_data , y_data = create_dataset(sequence)

# %%
len(x_data)
# Out:
# 274

# %%
x_data[0]
# Out:
# array([ 2, 27, 61, 62, 63, 28, 64,  3, 65, 66, 11, 67, 17, 18,  2, 29,  2,
#        30, 11, 68, 69,  9, 70,  5, 31, 19, 14,  2, 71,  8, 72,  5, 73,  4,
#        74, 32,  3, 75,  6, 33, 34, 12,  6, 35, 13,  4, 76, 36, 37, 38, 77,
#        20,  2, 39,  2, 40, 41,  7, 78, 15, 42, 79, 18,  2, 80, 16,  3, 81,
#        82, 83, 10,  7, 84,  4, 85,  3, 17, 86, 87, 43, 32, 36, 38, 88,  5,
#        21,  6, 89, 18,  2, 90,  2, 40, 91,  5, 92, 20,  6, 93, 13])

# %%
y_data[0]
# Out:
# array([27, 61, 62, 63, 28, 64,  3, 65, 66, 11, 67, 17, 18,  2, 29,  2, 30,
#        11, 68, 69,  9, 70,  5, 31, 19, 14,  2, 71,  8, 72,  5, 73,  4, 74,
#        32,  3, 75,  6, 33, 34, 12,  6, 35, 13,  4, 76, 36, 37, 38, 77, 20,
#         2, 39,  2, 40, 41,  7, 78, 15, 42, 79, 18,  2, 80, 16,  3, 81, 82,
#        83, 10,  7, 84,  4, 85,  3, 17, 86, 87, 43, 32, 36, 38, 88,  5, 21,
#         6, 89, 18,  2, 90,  2, 40, 91,  5, 92, 20,  6, 93, 13, 22])

# %%
class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
        angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.pos_encoding = tf.cast(angle_rads[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        return x + self.pos_encoding[:, :tf.shape(x)[1], :]

# %%
def transformer_block(embed_dim, num_heads, ff_dim, dropout=0.1):
    inputs = layers.Input(shape=(None, embed_dim))
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)(inputs, inputs)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(inputs + attn_output)

    ffn = tf.keras.Sequential([
        layers.Dense(ff_dim, activation='relu'),
        layers.Dense(embed_dim),
    ])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    out2 = layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)
    return tf.keras.Model(inputs=inputs, outputs=out2)

# %%
vocab_size = 5000
max_seq_len = 100
embed_dim = 256
num_heads = 8
ff_dim = 1024
num_layers = 96
batch_size = 32
epoch  = 10

def build_gpt_model():
    inputs = layers.Input(shape=(max_seq_len,))
    x = layers.Embedding(input_dim=vocab_size, output_dim=embed_dim)(inputs)
    x = PositionalEncoding(max_seq_len, embed_dim)(x)

    for _ in range(num_layers):
        x = transformer_block(embed_dim, num_heads, ff_dim)(x)

    outputs = layers.Dense(vocab_size, activation='softmax')(x)
    return tf.keras.Model(inputs, outputs)

# %%
model = build_gpt_model()
model.compile(optimizer='adam' , loss = 'sparse_categorical_crossentropy' , metrics=['accuracy'])

# %%
model.fit(x_data,y_data , batch_size=batch_size , epochs=epoch ,validation_split=.1)
# Out:
# Epoch 1/10
# 8/8 [==============================] - 1023s 96s/step - loss: 7.1827 - accuracy: 0.0489 - val_loss: 5.8732 - val_accuracy: 0.0600
# Epoch 2/10
# 8/8 [==============================] - 755s 94s/step - loss: 5.1649 - accuracy: 0.0575 - val_loss: 5.3122 - val_accuracy: 0.0689
# Epoch 3/10
# 8/8 [==============================] - 768s 98s/step - loss: 4.6902 - accuracy: 0.0557 - val_loss: 5.3350 - val_accuracy: 0.0600
# Epoch 4/10
# 8/8 [==============================] - 797s 98s/step - loss: 4.6453 - accuracy: 0.0560 - val_loss: 5.3132 - val_accuracy: 0.0689
# Epoch 5/10
# 8/8 [==============================] - 633s 79s/step - loss: 4.6381 - accuracy: 0.0551 - val_loss: 5.1930 - val_accuracy: 0.0600
# Epoch 6/10
# 8/8 [==============================] - 631s 79s/step - loss: 4.6311 - accuracy: 0.0561 - val_loss: 5.3072 - val_accuracy: 0.0689
# Epoch 7/10
# 8/8 [==============================] - 628s 79s/step - loss: 4.6291 - accuracy: 0.0559 - val_loss: 5.2812 - val_accuracy: 0.0600
# Epoch 8/10
# 8/8 [==============================] - 639s 80s/step - loss: 4.6301 - accuracy: 0.0571 - val_loss: 5.2021 - val_accuracy: 0.0689
# Epoch 9/10
# 8/8 [==============================] - 635s 79s/step - loss: 4.6251 - accuracy: 0.0566 - val_loss: 5.2698 - val_accuracy: 0.0600
# Epoch 10/10
# 8/8 [==============================] - 633s 79s/step - loss: 4.6328 - accuracy: 0.0573 - val_loss: 5.2761 - val_accuracy: 0.0689

# %%
model.save('gpt_test_genai_class.h5')
# Out:
# /opt/anaconda3/envs/genAI/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
model.summary()
# Out:
# Model: "model_96"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  embedding (Embedding)       (None, 100, 256)          1280000
#
#  positional_encoding (Posit  (None, 100, 256)          0
#  ionalEncoding)
#
#  model (Functional)          (None, None, 256)         2630144
#
#  model_1 (Functional)        (None, None, 256)         2630144
#
#  model_2 (Functional)        (None, None, 256)         2630144
#
#  model_3 (Functional)        (None, None, 256)         2630144
#
#  model_4 (Functional)        (None, None, 256)         2630144
#
#  model_5 (Functional)        (None, None, 256)         2630144
#
#  model_6 (Functional)        (None, None, 256)         2630144
#
#  model_7 (Functional)        (None, None, 256)         2630144
#
#  model_8 (Functional)        (None, None, 256)         2630144
#
#  model_9 (Functional)        (None, None, 256)         2630144
#
#  model_10 (Functional)       (None, None, 256)         2630144
#
#  model_11 (Functional)       (None, None, 256)         2630144
#
#  model_12 (Functional)       (None, None, 256)         2630144
#
#  model_13 (Functional)       (None, None, 256)         2630144
#
#  model_14 (Functional)       (None, None, 256)         2630144
#
#  model_15 (Functional)       (None, None, 256)         2630144
#
#  model_16 (Functional)       (None, None, 256)         2630144
#
#  model_17 (Functional)       (None, None, 256)         2630144
#
#  model_18 (Functional)       (None, None, 256)         2630144
#
#  model_19 (Functional)       (None, None, 256)         2630144
#
#  model_20 (Functional)       (None, None, 256)         2630144
#
#  model_21 (Functional)       (None, None, 256)         2630144
#
#  model_22 (Functional)       (None, None, 256)         2630144
#
#  model_23 (Functional)       (None, None, 256)         2630144
#
#  model_24 (Functional)       (None, None, 256)         2630144
#
#  model_25 (Functional)       (None, None, 256)         2630144
#
#  model_26 (Functional)       (None, None, 256)         2630144
#
#  model_27 (Functional)       (None, None, 256)         2630144
#
#  model_28 (Functional)       (None, None, 256)         2630144
#
#  model_29 (Functional)       (None, None, 256)         2630144
#
#  model_30 (Functional)       (None, None, 256)         2630144
#
#  model_31 (Functional)       (None, None, 256)         2630144
#
#  model_32 (Functional)       (None, None, 256)         2630144
#
#  model_33 (Functional)       (None, None, 256)         2630144
#
#  model_34 (Functional)       (None, None, 256)         2630144
#
#  model_35 (Functional)       (None, None, 256)         2630144
#
#  model_36 (Functional)       (None, None, 256)         2630144
#
#  model_37 (Functional)       (None, None, 256)         2630144
#
#  model_38 (Functional)       (None, None, 256)         2630144
#
#  model_39 (Functional)       (None, None, 256)         2630144
#
#  model_40 (Functional)       (None, None, 256)         2630144
#
#  model_41 (Functional)       (None, None, 256)         2630144
#
#  model_42 (Functional)       (None, None, 256)         2630144
#
#  model_43 (Functional)       (None, None, 256)         2630144
#
#  model_44 (Functional)       (None, None, 256)         2630144
#
#  model_45 (Functional)       (None, None, 256)         2630144
#
#  model_46 (Functional)       (None, None, 256)         2630144
#
#  model_47 (Functional)       (None, None, 256)         2630144
#
#  model_48 (Functional)       (None, None, 256)         2630144
#
#  model_49 (Functional)       (None, None, 256)         2630144
#
#  model_50 (Functional)       (None, None, 256)         2630144
#
#  model_51 (Functional)       (None, None, 256)         2630144
#
#  model_52 (Functional)       (None, None, 256)         2630144
#
#  model_53 (Functional)       (None, None, 256)         2630144
#
#  model_54 (Functional)       (None, None, 256)         2630144
#
#  model_55 (Functional)       (None, None, 256)         2630144
#
#  model_56 (Functional)       (None, None, 256)         2630144
#
#  model_57 (Functional)       (None, None, 256)         2630144
#
#  model_58 (Functional)       (None, None, 256)         2630144
#
#  model_59 (Functional)       (None, None, 256)         2630144
#
#  model_60 (Functional)       (None, None, 256)         2630144
#
#  model_61 (Functional)       (None, None, 256)         2630144
#
#  model_62 (Functional)       (None, None, 256)         2630144
#
#  model_63 (Functional)       (None, None, 256)         2630144
#
#  model_64 (Functional)       (None, None, 256)         2630144
#
#  model_65 (Functional)       (None, None, 256)         2630144
#
#  model_66 (Functional)       (None, None, 256)         2630144
#
#  model_67 (Functional)       (None, None, 256)         2630144
#
#  model_68 (Functional)       (None, None, 256)         2630144
#
#  model_69 (Functional)       (None, None, 256)         2630144
#
#  model_70 (Functional)       (None, None, 256)         2630144
#
#  model_71 (Functional)       (None, None, 256)         2630144
#
#  model_72 (Functional)       (None, None, 256)         2630144
#
#  model_73 (Functional)       (None, None, 256)         2630144
#
#  model_74 (Functional)       (None, None, 256)         2630144
#
#  model_75 (Functional)       (None, None, 256)         2630144
#
#  model_76 (Functional)       (None, None, 256)         2630144
#
#  model_77 (Functional)       (None, None, 256)         2630144
#
#  model_78 (Functional)       (None, None, 256)         2630144
#
#  model_79 (Functional)       (None, None, 256)         2630144
#
#  model_80 (Functional)       (None, None, 256)         2630144
#
#  model_81 (Functional)       (None, None, 256)         2630144
#
#  model_82 (Functional)       (None, None, 256)         2630144
#
#  model_83 (Functional)       (None, None, 256)         2630144
#
#  model_84 (Functional)       (None, None, 256)         2630144
#
#  model_85 (Functional)       (None, None, 256)         2630144
#
#  model_86 (Functional)       (None, None, 256)         2630144
#
#  model_87 (Functional)       (None, None, 256)         2630144
#
#  model_88 (Functional)       (None, None, 256)         2630144
#
#  model_89 (Functional)       (None, None, 256)         2630144
#
#  model_90 (Functional)       (None, None, 256)         2630144
#
#  model_91 (Functional)       (None, None, 256)         2630144
#
#  model_92 (Functional)       (None, None, 256)         2630144
#
#  model_93 (Functional)       (None, None, 256)         2630144
#
#  model_94 (Functional)       (None, None, 256)         2630144
#
#  model_95 (Functional)       (None, None, 256)         2630144
#
#  dense_192 (Dense)           (None, 100, 5000)         1285000
#
# =================================================================
# Total params: 255058824 (972.97 MB)
# Trainable params: 255058824 (972.97 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import tensorflow as tf
import pickle
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# Load trained model
model = tf.keras.models.load_model("gpt_test_genai_class.h5", custom_objects={"PositionalEncoding": PositionalEncoding})

# Load tokenizer
with open("tokenizer.pkl", "rb") as f:
    tokenizer = pickle.load(f)

# Parameters
max_seq_len = 100

# %%
def generate_text(seed_text, model, tokenizer, num_tokens=50, temperature=1.0):
    for _ in range(num_tokens):
        token_seq = tokenizer.texts_to_sequences([seed_text])[0]
        token_seq = token_seq[-max_seq_len:]  # Trim to max length
        padded_seq = pad_sequences([token_seq], maxlen=max_seq_len)

        preds = model.predict(padded_seq, verbose=0)[0, -1]  # Get prediction for last time step
        preds = np.asarray(preds).astype('float64')

        # Apply temperature sampling
        preds = np.log(preds + 1e-9) / temperature
        preds = np.exp(preds) / np.sum(np.exp(preds))

        next_token_id = np.random.choice(len(preds), p=preds)
        next_word = tokenizer.index_word.get(next_token_id, '')

        seed_text += ' ' + next_word

        if next_word == '':  # Optional: break if OOV or unknown word
            break

    return seed_text

# %%
seed_text = "who is Abhishek"
generated = generate_text(seed_text, model, tokenizer, num_tokens=50, temperature=1.0)

print("📝 Generated Text:")
print(generated)
# Out:
# 📝 Generated Text:
# who is Abhishek and my my with with of shadows filled top until began foot stumbled i deep my around presence small a watched the of it beckoning glow saw and a groaned i presence on i air room spun began to but light seemed down i i adorned was stumbled catch damp
